# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-elesbao/ExerciciosAnalisedeDadosBCC03.2022/blob/main/Tarefa12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Daniel Zamboni Elesbão - RA: 11202230222

#Tarefa 12 da disciplina Bases Computacionais da ciência

# %% [markdown]
#    **1)**  Três séries, $v, y$ e $t$ seguem as seguintes regras:
#
#    $$v[i] = v[i-1] + 0,01.(-9,81)$$
#    $$y[i] = y[i-1] + 0,01v[i-1]$$
#    $$t[i] = t[i-1] + 0,01$$
#
#    Começando com v[0] = 10 m/s, y[0] = 0 m e t[0] = 0 s, calcule os 250 primeiros valores das três séries.
#    Faça os gráficos com os valores encontrados de $y$ em função de $t$ e dos valores encontrados de $v$ em função de $t$.
#
#    Observação: o cálculo destas três séries é uma simulação computacional para calcular a posição e velocidade de uma partícula lançada na vertical com velocidade inicial de 10 m/s. O método utilizado para realizar esta simulação é conhecido como método de Euler.

# %%
#Cálculo de posição e velocidade de uma partícula lançada na vertical com velocidade inicial de 10 m/s pelo método de Euler.
import numpy as np #importa a biblioteca numpy como np
import matplotlib.pyplot as plt #importa a biblioteca mathplotlib como plt
v = np.zeros((250))
y = np.zeros((250))
t = np.zeros((250))
v[0] = 10
y[0] = 0
t[0] = 0
for i in range (1, 250):
  v[i] = v[i - 1] + 0.01 * (-9.81)
  y[i] = y[i - 1] + 0.01 * v[i - 1]
  t[i] = t[i - 1] + 0.01
plt.figure() #executa função que desenha o gráfico
plt.title('Velocidade em função do tempo')#Título do Gráfico
plt.plot (t , v) #cria o gráfico de velocidade em função do tempo
plt.show()
plt.title('Posição em função do tempo')#Título do Gráfico
plt.plot (t , y) #cria o gráfico de velocidade em função do tempo
plt.show() #exibe o gráfico

# %% [markdown]
# **2)** O valor de $\\ln(1+x)$ pode ser aproximado por (apenas para $|x|<1$)
#
# $$\ln(1+x) = x - \frac{x^2}{2} + \frac{x^3}{3} ... = \displaystyle\sum_{i=1}^n (-1)^{i+1}\frac{x^i}{i}$$
#
# $\ln$ é o logaritmo na base $e$ (conhecido como logaritmo natural).
#
# Use a expressão acima com n = 100 para encontrar $\\ln(0.5)$.
#
# Compare o resultado com a função do Numpy `np.log(0.5)`

# %%
#Cálculo da aproximação do logaritmo natural (ln) de 0.5
import numpy as np #importa a biblioteca numpy como np
x = (-0.5)
ln = 0
for n in range (1, 100): #laço que realiza os cálculos para n = 100
  if n%2==0: #condição que estabelece que se o termo for par realiza uma subtração, se for ímpar realiza uma soma
    ln -= ( x ** n) / n
  else:
    ln += ( x ** n) / n
if ln >=  np.log(0.5):
  dif = ln / np.log(0.5) * 100 #calcula a precisão do cálculo realizado
else:
  dif = np.log(0.5) / ln * 100 #calcula a precisão do cálculo realizado
print (f'O valor do logaritmo natural pela aproximação é {ln} e pela função numpy.log é {np.log(0.5)}, uma precisão de {dif}%') #exibe o resultado formatado
# Out:
# O valor do logaritmo natural pela aproximação é -0.6931471805599451 e pela função numpy.log é -0.6931471805599453, uma precisão de 99.99999999999997%

# %% [markdown]
# **3)** Calcular a aproximação de uma onda quadrada seguindo a seguinte expressão (a expressão abaixo é calculada utilizando uma teoria matemática conhecida como série de Fourier):
#
#
# $$x(t)  \approx \frac{4}{\pi}\displaystyle \sum_{i = 1}^N \frac{\sin\left[(2i - 1)t\right]}{2i - 1}$$
#
#
# Faça a aproximação para $0 \leqslant t \leqslant 10$ (utilize um número suficiente de pontos no vetor $t$ para poder observar o gráfico de $x(t)$, algo em torno de 100000 pontos).
#
# Faça a aproximação para a) N = 10, b) N = 100, c) N = 1000 e d) N = 10000. Coloque todas as aproximações em um único gráfico, com a aproximação de $x(t)$ em função de $t$.
#
# Dica: se você estiver com dificuldade, faça primeiro o gráfico considerando i = 1, sem nenhuma somatória (N = 1). Depois disso, coloque o código que você tiver escrito dentro de um for ou while para variar o valor de i e fazer a somatória.

# %%
#Calcula a aproximação de uma onda quadrada pela série de Fourier
import numpy as np #importa a biblioteca numpy como np
import matplotlib.pyplot as plt #importa a biblioteca mathplotlib como plt
t = np.linspace( 0, 10, 100000 )#cria o vetor t com 100000 pontos
N = [ 10, 100, 1000, 10000 ] #cria a matriz N com os valores a serem aproximados
plt.figure( ) #executa função que desenha o gráfico
for passo in N: #laço for para cada aproximação
  x = 0 #define a variável x e zera seu conteúdo
  for i in range ( 0, passo): #laço para realização do cálculo
    x += (4 / np.pi) * np.sin ( ( 2 * i - 1 ) * t ) / ( 2 * i - 1 ) #fórmula de onda fornecida pelo exercício
  plt.plot ( t , x , label = f'n={passo}' ) #cria o gráfico de x em função de t.
plt.xlabel( 'Período' )  #significado do eixo x
plt.ylabel( 'Onda' ) #significado do eixo y
plt.title( 'Aproximação de uma onda quadrada pela série de Fourier' ) #título do gráfico
plt.legend( ) #exibe as legendas
plt.show( ) #exibe o gráfico
